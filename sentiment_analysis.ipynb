# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup,NavigableString
data = pd.read_excel('/content/drive/MyDrive/blackcoffer/Output Data Structure (1).xlsx', header=0, skipfooter=0)
data.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0   123.0  https://insights.blackcoffer.com/rise-of-telem...             NaN
# 1   321.0  https://insights.blackcoffer.com/rise-of-e-hea...             NaN
# 2  2345.0  https://insights.blackcoffer.com/rise-of-e-hea...             NaN
# 3  4321.0  https://insights.blackcoffer.com/rise-of-telem...             NaN
# 4   432.0  https://insights.blackcoffer.com/rise-of-telem...             NaN
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0             NaN             NaN                 NaN                  NaN
# 1             NaN             NaN                 NaN                  NaN
# 2             NaN             NaN                 NaN                  NaN
# 3             NaN             NaN                 NaN                  NaN
# 4             NaN             NaN                 NaN                  NaN
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                          NaN        NaN                               NaN
# 1                          NaN        NaN                               NaN
# 2                          NaN        NaN                               NaN
# 3                          NaN        NaN                               NaN
# 4                          NaN        NaN                               NaN
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
import os

# Define the directory path
directory = 'data'

# Check if the directory already exists
if not os.path.exists(directory):
    os.makedirs(directory)

# Now, you can proceed with your code, which may include saving files to the 'data' directory.

# %%
#to create a folder for all the files
#import os
#os.makedirs('data')

# %%
#to read the title of the file from the urls
l=[]
for url in data['URL']:
    title=url.split('/')[3]
    file_name=title+'.html'
    file_path='./data/' + file_name
#to scrape the data from the url and save it to the file if the file doesnt exist in the directory
    if not os.path.exists(file_path):
        #print('file doesnt exists')
        with open(file_path,'w') as f:
            r = requests.get(url, headers={"User-Agent": "XY"})
            htmlcontent=r.content.decode()
            f.write(htmlcontent)
#to open each file and retrieve the beautifulsoup from the htmlcontent and put it in a dataframe
    with open (file_path,'r')as f:
        htmlcontent=f.read()
    soup = BeautifulSoup(htmlcontent, 'html.parser')
    title = soup.title
    article_content = soup.find('div', attrs={'class': 'td-post-content'})
    if article_content is None:
        #print('break')
        continue
    article_text=''
    for element in article_content:
        if not isinstance(element, NavigableString):
            text = element.text
            article_text+=text
    l.append(article_text)

df=pd.DataFrame(l,columns=['Text'])
df.head()
# Out:
#                                                 Text
# 0  Telemedicine, the use of technology to diagnos...
# 1  The rise of e-health, or the use of electronic...
# 2  \n/* custom css */\n.tdb_single_content{\n    ...
# 3  “More gains on quality, affordability and acce...
# 4  “More gains on quality, affordability and acce...

# %%
df.tail()
# Out:
#                                                   Text
# 107  Before jumping on the topic I would like to gi...
# 108  As the coronavirus spreads around the world an...
# 109  From Alibaba to Ping An and Google to Ford, co...
# 110  When\nthe British ruled India, many Indians\na...
# 111  The business of business is no longer to do ju...

# %%
import pandas as pd
outputfile=pd.read_excel('/content/drive/MyDrive/blackcoffer/Output Data Structure (1).xlsx')
outputfile.head()
outputfile.tail()
# Out:
#       URL_ID                                                URL  \
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
#      POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 109             NaN             NaN             NaN                 NaN
# 110             NaN             NaN             NaN                 NaN
# 111             NaN             NaN             NaN                 NaN
# 112             NaN             NaN             NaN                 NaN
# 113             NaN             NaN             NaN                 NaN
#
#      AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 109                  NaN                          NaN        NaN
# 110                  NaN                          NaN        NaN
# 111                  NaN                          NaN        NaN
# 112                  NaN                          NaN        NaN
# 113                  NaN                          NaN        NaN
#
#      AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 109                               NaN                 NaN         NaN
# 110                               NaN                 NaN         NaN
# 111                               NaN                 NaN         NaN
# 112                               NaN                 NaN         NaN
# 113                               NaN                 NaN         NaN
#
#      SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 109                NaN                NaN              NaN
# 110                NaN                NaN              NaN
# 111                NaN                NaN              NaN
# 112                NaN                NaN              NaN
# 113                NaN                NaN              NaN

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
l=[]
for i in range(112):

    example_sent = df['Text'][i]

    stop_words = set(stopwords.words('english'))

    word_tokens = word_tokenize(example_sent)

    filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

    filtered_sentence = []

    for w in word_tokens:
        if w not in stop_words:
            filtered_sentence.append(w)

    new_sentence=' '.join(filtered_sentence)
    l.append(new_sentence)
df=pd.DataFrame(l,columns=['Text'])

#print(word_tokens)
df.head()
# Out:
#                                                 Text
# 0  Telemedicine , use technology diagnose treat p...
# 1  The rise e-health , use electronic means facil...
# 2  / * custom css * / .tdb_single_content { margi...
# 3  “ More gains quality , affordability accessibi...
# 4  “ More gains quality , affordability accessibi...

# %%
data.tail()
# Out:
#       URL_ID                                                URL  \
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
#      POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 109             NaN             NaN             NaN                 NaN
# 110             NaN             NaN             NaN                 NaN
# 111             NaN             NaN             NaN                 NaN
# 112             NaN             NaN             NaN                 NaN
# 113             NaN             NaN             NaN                 NaN
#
#      AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 109                  NaN                          NaN        NaN
# 110                  NaN                          NaN        NaN
# 111                  NaN                          NaN        NaN
# 112                  NaN                          NaN        NaN
# 113                  NaN                          NaN        NaN
#
#      AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 109                               NaN                 NaN         NaN
# 110                               NaN                 NaN         NaN
# 111                               NaN                 NaN         NaN
# 112                               NaN                 NaN         NaN
# 113                               NaN                 NaN         NaN
#
#      SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 109                NaN                NaN              NaN
# 110                NaN                NaN              NaN
# 111                NaN                NaN              NaN
# 112                NaN                NaN              NaN
# 113                NaN                NaN              NaN

# %%
#to read the Positive-scores.txt file as a dataframe and changing the first entry


import pandas as pd
pw=pd.read_csv('../content/drive/MyDrive/blackcoffer/positive-words.txt')

new_row=pd.DataFrame({'a+':'a+'},index=[0])
pw=pd.concat([new_row,pw.loc[:].reset_index(drop=True)])
pw.columns=['0']
pw.reset_index(drop=True,inplace=True)
pw.head(100)
# Out:
#               0
# 0            a+
# 1        abound
# 2       abounds
# 3     abundance
# 4      abundant
# ..          ...
# 95   amiability
# 96     amiabily
# 97      amiable
# 98  amicability
# 99     amicable
#
# [100 rows x 1 columns]

# %%
 #code to find and enter the the positive score of each url file in the output file

for i in range(112):
    ps=0
    #print(type(df['Text'][i]))
    for word in pw['0']:

        if word in df['Text'][i].lower():
            ps+=1
    outputfile.at[i,'POSITIVE SCORE']=ps

outputfile.head()

outputfile.tail()
# Out:
#       URL_ID                                                URL  \
# 109  50921.0  https://insights.blackcoffer.com/coronavirus-i...
# 110  51382.8  https://insights.blackcoffer.com/coronavirus-i...
# 111  51844.6  https://insights.blackcoffer.com/what-are-the-...
# 112  52306.4  https://insights.blackcoffer.com/marketing-dri...
# 113  52768.2  https://insights.blackcoffer.com/continued-dem...
#
#      POSITIVE SCORE  NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 109            92.0             NaN             NaN                 NaN
# 110            49.0             NaN             NaN                 NaN
# 111            59.0             NaN             NaN                 NaN
# 112             NaN             NaN             NaN                 NaN
# 113             NaN             NaN             NaN                 NaN
#
#      AVG SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 109                  NaN                          NaN        NaN
# 110                  NaN                          NaN        NaN
# 111                  NaN                          NaN        NaN
# 112                  NaN                          NaN        NaN
# 113                  NaN                          NaN        NaN
#
#      AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 109                               NaN                 NaN         NaN
# 110                               NaN                 NaN         NaN
# 111                               NaN                 NaN         NaN
# 112                               NaN                 NaN         NaN
# 113                               NaN                 NaN         NaN
#
#      SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 109                NaN                NaN              NaN
# 110                NaN                NaN              NaN
# 111                NaN                NaN              NaN
# 112                NaN                NaN              NaN
# 113                NaN                NaN              NaN

# %%
#code to read and change the negative_words file data to a dataframe
import pandas as pd
with open('/content/drive/MyDrive/blackcoffer/negative-words new.txt', 'rb') as nw:
    words = [str(w)[2:-3]for w in nw]

    nw=pd.DataFrame(words,columns=['Negative_words'])

    print(nw)
# Out:
#      Negative_words
# 0           2-faced
# 1           2-faces
# 2          abnormal
# 3           abolish
# 4        abominable
# ...             ...
# 4778           zaps
# 4779         zealot
# 4780        zealous
# 4781      zealously
# 4782         zombie
#
# [4783 rows x 1 columns]

# %%
#code to find the negative score of each url file in the output file
for i in range(112):
    ns=0
    #print(type(df['Text'][i]))
    for word in nw['Negative_words']:

        if word in df['Text'][i].lower():
            ns+=1
    outputfile.at[i,'NEGATIVE SCORE']=ns

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0   123.0  https://insights.blackcoffer.com/rise-of-telem...            61.0
# 1   321.0  https://insights.blackcoffer.com/rise-of-e-hea...            31.0
# 2  2345.0  https://insights.blackcoffer.com/rise-of-e-hea...            39.0
# 3  4321.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
# 4   432.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            41.0             NaN                 NaN                  NaN
# 1            36.0             NaN                 NaN                  NaN
# 2            72.0             NaN                 NaN                  NaN
# 3            71.0             NaN                 NaN                  NaN
# 4            71.0             NaN                 NaN                  NaN
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                          NaN        NaN                               NaN
# 1                          NaN        NaN                               NaN
# 2                          NaN        NaN                               NaN
# 3                          NaN        NaN                               NaN
# 4                          NaN        NaN                               NaN
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
#polarity_score=(pos-nes)/((pos+nes)+0.000001)
for i in range(112):
    pols=0
    #print(type(df['Text'][i]))
    pos=outputfile['POSITIVE SCORE'][i]
    nes=outputfile['NEGATIVE SCORE'][i]
    pols=(pos-nes)/((pos+nes)+0.000001)


    outputfile.at[i,'POLARITY SCORE']=pols

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0   123.0  https://insights.blackcoffer.com/rise-of-telem...            61.0
# 1   321.0  https://insights.blackcoffer.com/rise-of-e-hea...            31.0
# 2  2345.0  https://insights.blackcoffer.com/rise-of-e-hea...            39.0
# 3  4321.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
# 4   432.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            41.0        0.196078                 NaN                  NaN
# 1            36.0       -0.074627                 NaN                  NaN
# 2            72.0       -0.297297                 NaN                  NaN
# 3            71.0       -0.036496                 NaN                  NaN
# 4            71.0       -0.036496                 NaN                  NaN
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                          NaN        NaN                               NaN
# 1                          NaN        NaN                               NaN
# 2                          NaN        NaN                               NaN
# 3                          NaN        NaN                               NaN
# 4                          NaN        NaN                               NaN
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
#SUBJECTIVITY SCORE=(pos+nes)/((total no.of words)+0.000001)
for i in range(112):

    #print(type(df['Text'][i]))
    text=df['Text'][i].split()
    pos=outputfile['POSITIVE SCORE'][i]
    nes=outputfile['NEGATIVE SCORE'][i]
    nofwords=len(text)
    subs=(pos+nes)/(nofwords+0.000001)


    outputfile.at[i,'SUBJECTIVITY SCORE']=subs

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0   123.0  https://insights.blackcoffer.com/rise-of-telem...            61.0
# 1   321.0  https://insights.blackcoffer.com/rise-of-e-hea...            31.0
# 2  2345.0  https://insights.blackcoffer.com/rise-of-e-hea...            39.0
# 3  4321.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
# 4   432.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            41.0        0.196078            0.086661                  NaN
# 1            36.0       -0.074627            0.169192                  NaN
# 2            72.0       -0.297297            0.087678                  NaN
# 3            71.0       -0.036496            0.151549                  NaN
# 4            71.0       -0.036496            0.151549                  NaN
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                          NaN        NaN                               NaN
# 1                          NaN        NaN                               NaN
# 2                          NaN        NaN                               NaN
# 3                          NaN        NaN                               NaN
# 4                          NaN        NaN                               NaN
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# AVG SENTENCE LENGTH

# %%
#avg sentence length= the number of words / the number of sentences
from nltk.tokenize import sent_tokenize,word_tokenize
for i in range(112):

    #print(type(df['Text'][i]))
    text=df['Text'][i]
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    nofsents=len(sent_tokenize(text))
    avgsl=(nofwords)/(nofsents+0.000001)


    outputfile.at[i,'AVG SENTENCE LENGTH']=avgsl

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0   123.0  https://insights.blackcoffer.com/rise-of-telem...            61.0
# 1   321.0  https://insights.blackcoffer.com/rise-of-e-hea...            31.0
# 2  2345.0  https://insights.blackcoffer.com/rise-of-e-hea...            39.0
# 3  4321.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
# 4   432.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            41.0        0.196078            0.086661            16.704918
# 1            36.0       -0.074627            0.169192            18.105262
# 2            72.0       -0.297297            0.087678            11.675676
# 3            71.0       -0.036496            0.151549            15.632653
# 4            71.0       -0.036496            0.151549            15.632653
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                          NaN        NaN                               NaN
# 1                          NaN        NaN                               NaN
# 2                          NaN        NaN                               NaN
# 3                          NaN        NaN                               NaN
# 4                          NaN        NaN                               NaN
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# COMPLEX WORD PERCENTAGE

# %%
#POCW=nofcw/nofwords
pofcw=0
for i in range(112):
    text=df['Text'][i]
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    vowels='aeiou'
    nofcw=0
    for w in word_list:
        vc=0 #vowelcount
        for v in vowels:
            if v in w:
                vc+=1
        if vc>1:
            nofcw+=1

    pofcw=nofcw/nofwords

    outputfile.at[i,'PERCENTAGE OF COMPLEX WORDS']=pofcw

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0   123.0  https://insights.blackcoffer.com/rise-of-telem...            61.0
# 1   321.0  https://insights.blackcoffer.com/rise-of-e-hea...            31.0
# 2  2345.0  https://insights.blackcoffer.com/rise-of-e-hea...            39.0
# 3  4321.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
# 4   432.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            41.0        0.196078            0.086661            16.704918
# 1            36.0       -0.074627            0.169192            18.105262
# 2            72.0       -0.297297            0.087678            11.675676
# 3            71.0       -0.036496            0.151549            15.632653
# 4            71.0       -0.036496            0.151549            15.632653
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.793916        NaN                               NaN
# 1                     0.863372        NaN                               NaN
# 2                     0.756944        NaN                               NaN
# 3                     0.788512        NaN                               NaN
# 4                     0.788512        NaN                               NaN
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
#fogi=0.4*(avgsl+pofcw)
fogi=0
for i in range(112):
    text=df['Text'][i]

    #to find avgsl
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    nofsents=len(sent_tokenize(text))
    avgsl=(nofwords)/(nofsents+0.000001)

    #to find pofcw
    vowels='aeiou'
    nofcw=0
    for w in word_list:
        vc=0 #vowelcount
        for v in vowels:
            if v in w:
                vc+=1
        if vc>1:
            nofcw+=1
    pofcw=nofcw/nofwords

    fogi=0.4*(avgsl+pofcw)

    outputfile.at[i,'FOG INDEX']=fogi

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0   123.0  https://insights.blackcoffer.com/rise-of-telem...            61.0
# 1   321.0  https://insights.blackcoffer.com/rise-of-e-hea...            31.0
# 2  2345.0  https://insights.blackcoffer.com/rise-of-e-hea...            39.0
# 3  4321.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
# 4   432.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            41.0        0.196078            0.086661            16.704918
# 1            36.0       -0.074627            0.169192            18.105262
# 2            72.0       -0.297297            0.087678            11.675676
# 3            71.0       -0.036496            0.151549            15.632653
# 4            71.0       -0.036496            0.151549            15.632653
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.793916   6.999533                               NaN
# 1                     0.863372   7.587454                               NaN
# 2                     0.756944   4.973048                               NaN
# 3                     0.788512   6.568466                               NaN
# 4                     0.788512   6.568466                               NaN
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# AVG NUMBER OF WORDS PER SENTENCE

# %%
#anofwps=nofwords/nofsents
for i in range(112):
    text=df['Text'][i]

    #to find avgsl
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    nofsents=len(sent_tokenize(text))
    anofwps=nofwords/nofsents

    outputfile.at[i,'AVG NUMBER OF WORDS PER SENTENCE']=anofwps

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0   123.0  https://insights.blackcoffer.com/rise-of-telem...            61.0
# 1   321.0  https://insights.blackcoffer.com/rise-of-e-hea...            31.0
# 2  2345.0  https://insights.blackcoffer.com/rise-of-e-hea...            39.0
# 3  4321.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
# 4   432.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            41.0        0.196078            0.086661            16.704918
# 1            36.0       -0.074627            0.169192            18.105262
# 2            72.0       -0.297297            0.087678            11.675676
# 3            71.0       -0.036496            0.151549            15.632653
# 4            71.0       -0.036496            0.151549            15.632653
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.793916   6.999533                         16.704918
# 1                     0.863372   7.587454                         18.105263
# 2                     0.756944   4.973048                         11.675676
# 3                     0.788512   6.568466                         15.632653
# 4                     0.788512   6.568466                         15.632653
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                 NaN         NaN                NaN                NaN
# 1                 NaN         NaN                NaN                NaN
# 2                 NaN         NaN                NaN                NaN
# 3                 NaN         NaN                NaN                NaN
# 4                 NaN         NaN                NaN                NaN
#
#    AVG WORD LENGTH
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
import nltk
nltk.download('cmudict')
# Out:
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# True

# %%
from nltk.corpus import cmudict

def count_complex_words(tokens):
    d = cmudict.dict()
    complex_word_count = 0

    for token in tokens:
        # Tokenize the word into phonemes
        phonemes = d.get(token.lower(), [])

        # Count the number of syllables
        #syllable_count = max(len(list(filter(lambda s: s[-1].isdigit(), phonemes)), 1)
        syllable_count = max(len(list(filter(lambda s: s[-1].isdigit(), phonemes))), 1)

        # You can define your own threshold for complexity
        if syllable_count >= 3:
            complex_word_count += 1

    return complex_word_count

for i in range(112):
    text = df['Text'][i]
    word_list = word_tokenize(text)

    # Define a threshold for word length to consider a word complex (adjust as needed)
    complex_word_length_threshold = 2

    complex_word_count = sum(1 for word in word_list if len(word) > complex_word_length_threshold)

    outputfile.at[i, 'COMPLEX WORD COUNT'] = complex_word_count

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0   123.0  https://insights.blackcoffer.com/rise-of-telem...            61.0
# 1   321.0  https://insights.blackcoffer.com/rise-of-e-hea...            31.0
# 2  2345.0  https://insights.blackcoffer.com/rise-of-e-hea...            39.0
# 3  4321.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
# 4   432.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            41.0        0.196078            0.086661            16.704918
# 1            36.0       -0.074627            0.169192            18.105262
# 2            72.0       -0.297297            0.087678            11.675676
# 3            71.0       -0.036496            0.151549            15.632653
# 4            71.0       -0.036496            0.151549            15.632653
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.793916   6.999533                         16.704918
# 1                     0.863372   7.587454                         18.105263
# 2                     0.756944   4.973048                         11.675676
# 3                     0.788512   6.568466                         15.632653
# 4                     0.788512   6.568466                         15.632653
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0              1003.0      1019.0             2991.0                0.0
# 1               342.0       344.0             1022.0                0.0
# 2               867.0       864.0             2332.0                0.0
# 3               758.0       766.0             2047.0                2.0
# 4               758.0       766.0             2047.0                2.0
#
#    AVG WORD LENGTH
# 0         7.396467
# 1         7.546512
# 2         7.627315
# 3         7.133159
# 4         7.133159

# %% [markdown]
# COMPLEX WORD COUNT

# %%
#remove the stop words
#remove the punctuations
for i in range(112):
    text=df['Text'][i]

    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)
    outputfile.at[i,'WORD COUNT']=nofwords
outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0   123.0  https://insights.blackcoffer.com/rise-of-telem...            61.0
# 1   321.0  https://insights.blackcoffer.com/rise-of-e-hea...            31.0
# 2  2345.0  https://insights.blackcoffer.com/rise-of-e-hea...            39.0
# 3  4321.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
# 4   432.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            41.0        0.196078            0.086661            16.704918
# 1            36.0       -0.074627            0.169192            18.105262
# 2            72.0       -0.297297            0.087678            11.675676
# 3            71.0       -0.036496            0.151549            15.632653
# 4            71.0       -0.036496            0.151549            15.632653
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.793916   6.999533                         16.704918
# 1                     0.863372   7.587454                         18.105263
# 2                     0.756944   4.973048                         11.675676
# 3                     0.788512   6.568466                         15.632653
# 4                     0.788512   6.568466                         15.632653
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0              1003.0      1019.0             2991.0                0.0
# 1               342.0       344.0             1022.0                0.0
# 2               867.0       864.0             2332.0                0.0
# 3               758.0       766.0             2047.0                2.0
# 4               758.0       766.0             2047.0                2.0
#
#    AVG WORD LENGTH
# 0         7.396467
# 1         7.546512
# 2         7.627315
# 3         7.133159
# 4         7.133159

# %% [markdown]
# SYLLABLE COUNT PER WORD

# %%
#scpw=total no. of syllables in the text/total no of words
for i in range(112):
    text=df['Text'][i]
    vowels='aeiou'
    nofs=0
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)

    nofwords=len(word_list)
    for l in text:
        if l in vowels:
            nofs+=1

    scpw=nofs/nofwords



    outputfile.at[i,'SYLLABLE PER WORD']=nofs

outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0   123.0  https://insights.blackcoffer.com/rise-of-telem...            61.0
# 1   321.0  https://insights.blackcoffer.com/rise-of-e-hea...            31.0
# 2  2345.0  https://insights.blackcoffer.com/rise-of-e-hea...            39.0
# 3  4321.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
# 4   432.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            41.0        0.196078            0.086661            16.704918
# 1            36.0       -0.074627            0.169192            18.105262
# 2            72.0       -0.297297            0.087678            11.675676
# 3            71.0       -0.036496            0.151549            15.632653
# 4            71.0       -0.036496            0.151549            15.632653
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.793916   6.999533                         16.704918
# 1                     0.863372   7.587454                         18.105263
# 2                     0.756944   4.973048                         11.675676
# 3                     0.788512   6.568466                         15.632653
# 4                     0.788512   6.568466                         15.632653
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0              1003.0      1019.0             2991.0                0.0
# 1               342.0       344.0             1022.0                0.0
# 2               867.0       864.0             2332.0                0.0
# 3               758.0       766.0             2047.0                2.0
# 4               758.0       766.0             2047.0                2.0
#
#    AVG WORD LENGTH
# 0         7.396467
# 1         7.546512
# 2         7.627315
# 3         7.133159
# 4         7.133159

# %% [markdown]
# PERSONAL PRONOUNS

# %%
pp = ['I', 'we', 'We', 'WE', 'my', 'My', 'MY', 'ours', 'OURS', 'Ours', 'us', 'Us']  # Adjust the list to match the text
ppc_results = []

for i in range(112):
# Sample text for testing
    text = df['Text'][i]

    ppc = 0
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    for w in word_list:
        if w in pp:
             ppc += 1
    ppc_results.append(ppc)
    outputfile.at[i,'PERSONAL PRONOUNS']=ppc
outputfile.head()

    #print("PERSONAL PRONOUNS:", ppc_results)
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0   123.0  https://insights.blackcoffer.com/rise-of-telem...            61.0
# 1   321.0  https://insights.blackcoffer.com/rise-of-e-hea...            31.0
# 2  2345.0  https://insights.blackcoffer.com/rise-of-e-hea...            39.0
# 3  4321.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
# 4   432.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            41.0        0.196078            0.086661            16.704918
# 1            36.0       -0.074627            0.169192            18.105262
# 2            72.0       -0.297297            0.087678            11.675676
# 3            71.0       -0.036496            0.151549            15.632653
# 4            71.0       -0.036496            0.151549            15.632653
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.793916   6.999533                         16.704918
# 1                     0.863372   7.587454                         18.105263
# 2                     0.756944   4.973048                         11.675676
# 3                     0.788512   6.568466                         15.632653
# 4                     0.788512   6.568466                         15.632653
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0              1003.0      1019.0             2991.0                0.0
# 1               342.0       344.0             1022.0                0.0
# 2               867.0       864.0             2332.0                0.0
# 3               758.0       766.0             2047.0                2.0
# 4               758.0       766.0             2047.0                2.0
#
#    AVG WORD LENGTH
# 0         7.396467
# 1         7.546512
# 2         7.627315
# 3         7.133159
# 4         7.133159

# %% [markdown]
# AVERAGE WORD LENGTH

# %%
#avgwl=sum of the no of chars in each word/total no ofwords
for i in range(112):
    text=df['Text'][i]
    #to find no. of words
    clean_text = ''.join((c for c in text if c.isalpha() or c.isspace()))
    word_list = word_tokenize(clean_text)
    nofwords=len(word_list)

    #to find sum of chars
    nofc=0
    for w in word_list:
        cpw=len(w)
        nofc+=cpw
    avgwl=nofc/nofwords


    outputfile.at[i,'AVG WORD LENGTH']=avgwl
outputfile.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0   123.0  https://insights.blackcoffer.com/rise-of-telem...            61.0
# 1   321.0  https://insights.blackcoffer.com/rise-of-e-hea...            31.0
# 2  2345.0  https://insights.blackcoffer.com/rise-of-e-hea...            39.0
# 3  4321.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
# 4   432.0  https://insights.blackcoffer.com/rise-of-telem...            66.0
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0            41.0        0.196078            0.086661            16.704918
# 1            36.0       -0.074627            0.169192            18.105262
# 2            72.0       -0.297297            0.087678            11.675676
# 3            71.0       -0.036496            0.151549            15.632653
# 4            71.0       -0.036496            0.151549            15.632653
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                     0.793916   6.999533                         16.704918
# 1                     0.863372   7.587454                         18.105263
# 2                     0.756944   4.973048                         11.675676
# 3                     0.788512   6.568466                         15.632653
# 4                     0.788512   6.568466                         15.632653
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0              1003.0      1019.0             2991.0                0.0
# 1               342.0       344.0             1022.0                0.0
# 2               867.0       864.0             2332.0                0.0
# 3               758.0       766.0             2047.0                2.0
# 4               758.0       766.0             2047.0                2.0
#
#    AVG WORD LENGTH
# 0         7.396467
# 1         7.546512
# 2         7.627315
# 3         7.133159
# 4         7.133159

# %%
#/content/drive/MyDrive/blackcoffer/Output Data Structure.xlsx
outputfile.to_csv('/content/drive/MyDrive/blackcoffer/Output Data Structure (1).xlsx', index=False)
